# %% [markdown]
# ## Unrestricted atom number

# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/009/wIRwGR_ETA_results.dat',\
        eta_contours = [1.8, 3.2, 6., 8., 10.],\
        g0_contours  = [1.2, 2.0, 3.2, 3.8, 4.05],\
        sn_contours  = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = [3., 6.],\
        xlim=(45.,71.),
        dashed_eta=[{'slope':1.06,'c':'black'}],\
        dashed_g0=None,\
        dashed_sn=[{'slope':0.96,'c':'black'}],\
        dashed_num=[{'slope':1.16,'c':'black'}] \
        )
fig.savefig('EtaF_data/009/etaF-wIRwGR.png', dpi=300)

# %% [markdown]
# ## Unrestricted atom number, colder temperature T=0.2

# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/015/wIRwGR_ETA_results.dat',\
        eta_contours = [1.6, 3.2, 6., 8., 10.],\
        g0_contours  = [1.2, 2.0, 3.2, 3.7],\
        sn_contours  = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = [3., 6.],\
        xlim=(55.,71.),
        ylim=(38.,71.),
        xm=58.,
        dx=2.4,
        dashed_eta=[{'slope':1.06,'c':'black'}],\
        dashed_g0=None,\
        dashed_sn=[{'slope':1.00,'c':'black'}],\
        dashed_num=[{'slope':1.10,'c':'black'},{'slope':1.20,'c':'black'}], \
        blackout = (1.20, 1.10)\
        )
fig.savefig('EtaF_data/015/etaF-wIRwGR.png', dpi=300)

# %%
import optevap
fig = optevap.plotOptSingle(  'EtaF_data/009/wIRwGR_ETA_results.dat', 8,\
        contours = [ 0.57],\
        xlim=(45.,71.),
        dashed=[\
                {'slope':0.96,'c':'black'},\
                {'slope':1.16,'c':'black'}
                ],\
        title = '$\mathrm{HWHM}/w_{L}$') 

fig.savefig('EtaF_data/009/etaF-HWHM-ratio.png', dpi=300)

# %%
def wL( Num ) :
    return (Num / (4./3.*np.pi ))**(1./3.) * 0.532 / 0.47 
    
print wL( 5e5 )
# Out:
# 55.7323778319

# %% [markdown]
# ## Atom number restricted to 500,000

# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/010/wIRwGR_ETA_results.dat',\
        eta_contours = [2.8, 6., 8., 10.],\
        g0_contours  = [2.6, 4.08],\
        sn_contours  = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = [2.0, 4. ],\
        xlim=(55.,84.),
        ylim=(55.,94.),\
        xm=63.,\
        dashed_eta=[{'slope':0.96,'c':'black'},\
                    {'slope':0.82,'c':'black'},\
                    ],\
        dashed_g0=[{'slope':0.96,'c':'black'},\
                    {'slope':0.82,'c':'black'},\
                    ],\
        dashed_sn=[{'slope':0.96,'c':'black'},\
                     {'slope':0.82,'c':'black'},\
                   ],\
        dashed_num=[{'slope':0.96,'c':'black'},\
                     {'slope':0.82,'c':'black'},\
                    ] \
        )
fig.savefig('EtaF_data/010/etaF-wIRwGR.png', dpi=300)

# %% [markdown]
# ## Finding the necessary green to be able to lock to 30 Er,  how bad does it look?  The plots for this were run at various temperatures

# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/013/wIRwGR_ETA_results.dat',\
        eta_contours = [ 2.8, 4., 6., 8., 10.],\
        g0_contours  = [ 2.2, 3.0, 3.8],\
        sn_contours  = [2.6], \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = [2., 3., 3.8],\
        xm=63., dx=2.6,\
        xlim=(55.,74.),\
        ylim=(48.,79.),\
        dashed_eta=[{'slope':0.96,'c':'black'}],\
        dashed_g0=[{'slope':0.96,'c':'black'}],\
        dashed_sn=[{'slope':0.96,'c':'black'}],\
        dashed_num=[{'slope':0.96,'c':'black'}] \
        )
fig.savefig('EtaF_data/013/etaF-wIRwGR_r032.png', dpi=300)

# %%
import optevap
fig = optevap.plotOptSingle(  'EtaF_data/014/wIRwGR_ETA_results.dat', 8,\
        contours = [ 0.57],\
        xlim=(55.,71.),
        ylim=(38.,71.),
        xm=60, dx=3.0,
        dashed=[\
                {'slope':0.94,'c':'black'},\
                ],\
        title = '$\mathrm{HWHM}/w_{L}$') 

fig.savefig('EtaF_data/014/etaF-HWHM-ratio.png', dpi=300)

# %% [markdown]
# ## Plotting the resulting profiles

# %%
profs = [ 
        #0  Our setup, optimal green, high temperature 0.4 
        {'wIR':47.,\
         'wGR':40.,\
         'g0':4.006,\
         's0':7.,\
         'extents':80.,\
         'T':0.4,\
        },
        #1  Our setup, optimal green, med temperature 0.2 
        {'wIR':47.,\
         'wGR':40.,\
         'g0':4.006,\
         's0':7.,\
         'extents':46.5,\
         'T':0.2,\
        },
        #2  Our setup, our number, med temperature
        {'wIR':47.,\
         'wGR':40.,\
         'g0':3.325,\
         's0':7.,\
         'extents':30.,\
         'T':0.2,\
        },
        #3  Our setup, our number, low temperature 0.12
        {'wIR':47.,\
         'wGR':40.,\
         'g0':3.44,\
         's0':7.,\
         'extents':30.,\
         'T':0.12,\
        },
        #4  Harmonic conf.,  same N as optimal green, half-filling, med temperature 0.2
        {'wIR':500.,\
         'wGR':120.,\
         'g0':-2.035,\
         's0':7.,\
         'extents':50.,\
         'T':0.2,\
        },
        #5  Harmonic conf.,  N=3e5, half-filling, low temperature 0.12
        {'wIR':500.,\
         'wGR':120.,\
         'g0':-4.24,\
         's0':7.,\
         'extents':45.,\
         'T':0.12,\
        },
        #6  alpha=0.93, N=200,000, works for locking  up to ~40Er
        {'wIR':68.,\
         'wGR':75.,\
         'g0':4.28,\
         's0':7.,\
         'extents':35.,\
         'T':0.12,\
        },
        #7  alpha=0.97, N=300,000, works for locking up to ~32Er
        {'wIR':68.,\
         'wGR':70.5,\
         'g0':4.28,\
         's0':7.,\
         'extents':35.,\
         'T':0.12,\
        },
        #8  alpha=1.0,  N=384,000, works for locking up to ~24Er
        {'wIR':68.,\
         'wGR':68.,\
         'g0':4.28,\
         's0':7.,\
         'extents':40.,\
         'T':0.12,\
        },
        ]

import scubic
import lda

tags = range(9) 
#tags = [6,7,8] 

for tag in tags:
    print '\n',tag

    s       = profs[tag]['s0']
    g       = profs[tag]['g0']
    wIR     = profs[tag]['wIR']
    wGR     = profs[tag]['wGR']
    T       = profs[tag]['T'] 
    extents = profs[tag]['extents']
    
    pot = scubic.sc(allIR=s, allGR=g, allIRw=wIR, allGRw=wGR)
    test = lda.lda(potential = pot, Temperature=T, a_s=650., extents=extents, globalMu='halfMott', verbose=True, ignoreExtents=False)
    fig = lda.plotLine( test , line_direction='111', extents=extents, x1lims=(-80.,80.), x2lims=(-50.,50.)) 
    print test.getRadius()/wIR
    print test.Number
    plt.close()
    fig.savefig('EtaF_data/profiles/%03d.png'%tag, dpi=300)
# Out:
# 0
# OK: Bottom of the band has positive slope up to r111 = 10 um
# bandOrigin = -13.91
# band100 = -4.64
# 0.245369142754
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# 0.752351097179
# 1682852.1789
# 1
# OK: Bottom of the band has positive slope up to r111 = 10 um
# bandOrigin = -13.91
# band100 = -4.64
# 0.245369142754
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# 0.691622757287
# 1037197.46088
# 2
# OK: Bottom of the band has positive slope up to r111 = 10 um
# bandOrigin = -13.91
# band100 = -4.64
# 0.245369142754
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# ...

# %% [markdown]
# ## from below on tests...

# %%
    import optevap 

fig = optevap.plotOptimal( 'EtaF_data/005/wIRwGR_ETA_results.dat' )
fig.savefig('EtaF_data/005/etaF-wIRwGR.png', dpi=300)

# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/006/wIRwGR_ETA_results.dat',\
        eta_contours = [1.6, 3.4, 6., 8., 10.],\
        g0_contours  = [0.8, 1.6, 2.8, 3.8, 4.1],\
        sn_contours  = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = None)
fig.savefig('EtaF_data/006/etaF-wIRwGR.png', dpi=300)

# %% [markdown]
# ## Understanding how can $\eta=1$ for a large beam waist with moderate atom number

# %%
import scubic
import lda

s0 = 10. 
g0 = -10.0
a_s = 600.


pot = scubic.sc(allIR=s0, allGR=g0, allIRw=500., allGRw=120.)
test = lda.lda(potential = pot, Temperature=0.04, a_s=a_s, globalMu='halfMott', verbose=True )
test.TrapFreqs()
fig1 = lda.plotLine( test , line_direction='111')
# Out:
# OK: Bottom of the band has positive slope up to r111 = 10 um
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# [533.26362972683694, 533.26362972683694, 533.26362972685331]

# %%
import scubic
import lda

s0 = 7. 
g0 = 4.35231
a_s = 650.


pot = scubic.sc(allIR=s0, allGR=g0, allIRw=60., allGRw=65.)
test = lda.lda(potential = pot, Temperature=0.2, a_s=a_s, globalMu='halfMott', verbose=True )
test.TrapFreqs()
fig1 = lda.plotLine( test , line_direction='111')
# Out:
# OK: Bottom of the band has positive slope up to r111 = 10 um
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# [425.58363912482781, 425.58363912482758, 425.5836391248277]

# %%
import scubic
import lda

s0 = 7. 
g0 = 4.13
a_s = 1240.


pot = scubic.sc(allIR=s0, allGR=g0, allIRw=48., allGRw=50.)
test = lda.lda(potential = pot, Temperature=0.19, a_s=a_s, globalMu='halfMott', verbose=True )
test.TrapFreqs()
fig1 = lda.plotLine( test , line_direction='111')
# Out:
# OK: Bottom of the band has positive slope up to r111 = 10 um
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# [505.50294177253824, 505.50294177253824, 505.50294177253858]

# %%
import scubic
import lda

s0 = 7. 
g0 = 4.03
a_s = 650.


pot = scubic.sc(allIR=s0, allGR=g0, allIRw=48., allGRw=50.)
test = lda.lda(potential = pot, a_s=a_s, globalMu='halfMott', verbose=True )
test.TrapFreqs()
fig1 = lda.plotLine( test , line_direction='111') 
fig2 = lda.plotLine( test , line_direction='100') 
fig3 = lda.plotMathy( test , line_direction='111')
# Out:
# OK: Bottom of the band has positive slope up to r111 = 10 um
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# [519.80537544529273, 519.8053754452925, 519.80537544529216]
