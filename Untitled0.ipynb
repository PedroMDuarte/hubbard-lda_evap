# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/004/wIRwGR_ETA_results.dat',\
        eta_contours = [1.6, 3.4, 6., 8., 10.],\
        g0_contours  = [0.8, 1.6, 2.8, 3.8, 4.1],\
        sn_contours  = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = None)
fig.savefig('EtaF_data/004/etaF-wIRwGR.png', dpi=300)

# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/005/wIRwGR_ETA_results.dat' )
fig.savefig('EtaF_data/005/etaF-wIRwGR.png', dpi=300)

# %%
import optevap 

fig = optevap.plotOptimal( 'EtaF_data/006/wIRwGR_ETA_results.dat',\
        eta_contours = [1.6, 3.4, 6., 8., 10.],\
        g0_contours  = [0.8, 1.6, 2.8, 3.8, 4.1],\
        sn_contours  = None, \
        #[1.2, 1.4, 1.9, 2.4, 3.],\
        num_contours = None)
fig.savefig('EtaF_data/006/etaF-wIRwGR.png', dpi=300)

# %% [markdown]
# ## Understanding how can $\eta=1$ for a large beam waist with moderate atom number

# %%
import scubic
import lda

s0 = 7. 
g0 = 4.03
a_s = 650.


pot = scubic.sc(allIR=s0, allGR=g0, allIRw=48., allGRw=50.)
test = lda.lda(potential = pot, a_s=a_s, globalMu='halfMott', verbose=True )
test.TrapFreqs()
fig1 = lda.plotLine( test , line_direction='111') 
fig2 = lda.plotLine( test , line_direction='100') 
fig3 = lda.plotMathy( test , line_direction='111')
# Out:
# OK: Bottom of the band has positive slope up to r111 = 10 um
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# OK: Radial density profile along 111 decreases monotonically.
# [519.80537544529273, 519.8053754452925, 519.80537544529216]
